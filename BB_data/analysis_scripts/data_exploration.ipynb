# %%
from functions.data_functions import load_data
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt

# %%
t1_df = load_data('BEACON', 't1_measures')
t2_df = load_data('BEACON', 't2_measures')

# %%
fig,ax = plt.subplots(6,2, figsize=(10,20))
sns.boxplot(x='group', y='bmi_t1', data=t1_df, linewidth=1, palette='Accent_r', ax=ax[0][0])
sns.stripplot(x="group", y="bmi_t1", data=t1_df, color=".15", ax=ax[0][0])
sns.boxplot(x='group', y='bmi_t2', data=t2_df, linewidth=1, palette='Accent_r', ax=ax[0][1])
sns.stripplot(x="group", y="bmi_t2", data=t2_df, color=".15", ax=ax[0][1])

sns.boxplot(x='group', y='anxiety_t1', data=t1_df, linewidth=1, palette='Accent_r', ax=ax[1][0])
sns.stripplot(x="group", y="anxiety_t1", data=t1_df, color=".15", ax=ax[1][0])
sns.boxplot(x='group', y='anxiety_t2', data=t2_df, linewidth=1, palette='Accent_r', ax=ax[1][1])
sns.stripplot(x="group", y="anxiety_t2", data=t2_df, color=".15", ax=ax[1][1])

sns.boxplot(x='group', y='depression_t1', data=t1_df, linewidth=1, palette='Accent_r', ax=ax[2][0])
sns.stripplot(x="group", y="depression_t1", data=t1_df, color=".15", ax=ax[2][0])
sns.boxplot(x='group', y='depression_t2', data=t2_df, linewidth=1, palette='Accent_r', ax=ax[2][1])
sns.stripplot(x="group", y="depression_t2", data=t2_df, color=".15", ax=ax[2][1])

sns.boxplot(x='group', y='global_score_t1', data=t1_df, linewidth=1, palette='Accent_r', ax=ax[3][0])
sns.stripplot(x="group", y="global_score_t1", data=t1_df, color=".15", ax=ax[3][0])
sns.boxplot(x='group', y='global_score_t2', data=t2_df, linewidth=1, palette='Accent_r', ax=ax[3][1])
sns.stripplot(x="group", y="global_score_t2", data=t2_df, color=".15", ax=ax[3][1])

sns.boxplot(x='group', y='aq_score_t1', data=t1_df, linewidth=1, palette='Accent_r', ax=ax[4][0])
sns.stripplot(x="group", y="aq_score_t1", data=t1_df, color=".15", ax=ax[4][0])
sns.boxplot(x='group', y='aq_score_t2', data=t2_df, linewidth=1, palette='Accent_r', ax=ax[4][1])
sns.stripplot(x="group", y="aq_score_t2", data=t2_df, color=".15", ax=ax[4][1])

sns.boxplot(x='group', y='wsas_score_t1', data=t1_df, linewidth=1, palette='Accent_r', ax=ax[5][0])
sns.stripplot(x="group", y="wsas_score_t1", data=t1_df, color=".15", ax=ax[5][0])
sns.boxplot(x='group', y='wsas_score_t2', data=t2_df, linewidth=1, palette='Accent_r', ax=ax[5][1])
sns.stripplot(x="group", y="wsas_score_t2", data=t2_df, color=".15", ax=ax[5][1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [4], line 9
#       7 sns.boxplot(x='group', y='anxiety_t1', data=t1_df, linewidth=1, palette='Accent_r', ax=ax[1][0])
#       8 sns.stripplot(x="group", y="anxiety_t1", data=t1_df, color=".15", ax=ax[1][0])
# ----> 9 sns.boxplot(x='group', y='anxiety_t2', data=t2_df, linewidth=1, palette='Accent_r', ax=ax[1][1])
#      10 sns.stripplot(x="group", y="anxiety_t2", data=t2_df, color=".15", ax=ax[1][1])
#      12 sns.boxplot(x='group', y='depression_t1', data=t1_df, linewidth=1, palette='Accent_r', ax=ax[2][0])
#
# File ~/Codes/work/BB_data/venv/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
# ...
