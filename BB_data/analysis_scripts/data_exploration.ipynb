# %% [markdown]
# # Data description
#
# Notebook used for exploratory data analysis

# %%
from functions.data_functions import load_data, load_pickle
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import pandas as pd
import ptitprince as pt

# %% [markdown]
# ## Raw scores description

# %%
data = load_data('BEACON', 'imputated_combined_data')
t1_df = data[['G_Number', 'aq_score_t1', 'anxiety_t1', 'depression_t1',
       'bmi_t1', 'oci_score_t1', 'wsas_score_t1', 'restraint_score_t1',
       'eating_concern_score_t1', 'shape_concern_score_t1',
       'weight_concern_score_t1', 'group']]
t2_df = data[[ 'B_Number', 'aq_score_t2', 'anxiety_t2', 'depression_t2', 'bmi_t2', 'oci_score_t2',
       'wsas_score_t2', 'restraint_score_t2', 'eating_concern_score_t2',
       'shape_concern_score_t2', 'weight_concern_score_t2', 'group']]

# %%
pca_df = load_data('BEACON', 'pca_df')
comp = ['comp_1', 'comp_2','comp_3']

# %%
fig,ax = plt.subplots(9,2, figsize=(10,20))
sns.boxplot(x='group', y='bmi_t1', data=t1_df, linewidth=1, palette='Accent_r', ax=ax[0][0])
sns.stripplot(x="group", y="bmi_t1", data=t1_df, color=".15", ax=ax[0][0])
sns.boxplot(x='group', y='bmi_t2', data=t2_df, linewidth=1, palette='Accent_r', ax=ax[0][1])
sns.stripplot(x="group", y="bmi_t2", data=t2_df, color=".15", ax=ax[0][1])

sns.boxplot(x='group', y='anxiety_t1', data=t1_df, linewidth=1, palette='Accent_r', ax=ax[1][0])
sns.stripplot(x="group", y="anxiety_t1", data=t1_df, color=".15", ax=ax[1][0])
sns.boxplot(x='group', y='anxiety_t2', data=t2_df, linewidth=1, palette='Accent_r', ax=ax[1][1])
sns.stripplot(x="group", y="anxiety_t2", data=t2_df, color=".15", ax=ax[1][1])

sns.boxplot(x='group', y='depression_t1', data=t1_df, linewidth=1, palette='Accent_r', ax=ax[2][0])
sns.stripplot(x="group", y="depression_t1", data=t1_df, color=".15", ax=ax[2][0])
sns.boxplot(x='group', y='depression_t2', data=t2_df, linewidth=1, palette='Accent_r', ax=ax[2][1])
sns.stripplot(x="group", y="depression_t2", data=t2_df, color=".15", ax=ax[2][1])

sns.boxplot(x='group', y='restraint_score_t1', data=t1_df, linewidth=1, palette='Accent_r', ax=ax[3][0])
sns.stripplot(x="group", y="restraint_score_t1", data=t1_df, color=".15", ax=ax[3][0])
sns.boxplot(x='group', y='restraint_score_t2', data=t2_df, linewidth=1, palette='Accent_r', ax=ax[3][1])
sns.stripplot(x="group", y="restraint_score_t2", data=t2_df, color=".15", ax=ax[3][1])

sns.boxplot(x='group', y='eating_concern_score_t1', data=t1_df, linewidth=1, palette='Accent_r', ax=ax[4][0])
sns.stripplot(x="group", y="eating_concern_score_t1", data=t1_df, color=".15", ax=ax[4][0])
sns.boxplot(x='group', y='eating_concern_score_t2', data=t2_df, linewidth=1, palette='Accent_r', ax=ax[4][1])
sns.stripplot(x="group", y="eating_concern_score_t2", data=t2_df, color=".15", ax=ax[4][1])

sns.boxplot(x='group', y='shape_concern_score_t1', data=t1_df, linewidth=1, palette='Accent_r', ax=ax[5][0])
sns.stripplot(x="group", y="shape_concern_score_t1", data=t1_df, color=".15", ax=ax[5][0])
sns.boxplot(x='group', y='shape_concern_score_t2', data=t2_df, linewidth=1, palette='Accent_r', ax=ax[5][1])
sns.stripplot(x="group", y="shape_concern_score_t2", data=t2_df, color=".15", ax=ax[5][1])

sns.boxplot(x='group', y='weight_concern_score_t1', data=t1_df, linewidth=1, palette='Accent_r', ax=ax[6][0])
sns.stripplot(x="group", y="weight_concern_score_t1", data=t1_df, color=".15", ax=ax[6][0])
sns.boxplot(x='group', y='weight_concern_score_t2', data=t2_df, linewidth=1, palette='Accent_r', ax=ax[6][1])
sns.stripplot(x="group", y="weight_concern_score_t2", data=t2_df, color=".15", ax=ax[6][1])

sns.boxplot(x='group', y='aq_score_t1', data=t1_df, linewidth=1, palette='Accent_r', ax=ax[7][0])
sns.stripplot(x="group", y="aq_score_t1", data=t1_df, color=".15", ax=ax[7][0])
sns.boxplot(x='group', y='aq_score_t2', data=t2_df, linewidth=1, palette='Accent_r', ax=ax[7][1])
sns.stripplot(x="group", y="aq_score_t2", data=t2_df, color=".15", ax=ax[7][1])

sns.boxplot(x='group', y='wsas_score_t1', data=t1_df, linewidth=1, palette='Accent_r', ax=ax[8][0])
sns.stripplot(x="group", y="wsas_score_t1", data=t1_df, color=".15", ax=ax[8][0])
sns.boxplot(x='group', y='wsas_score_t2', data=t2_df, linewidth=1, palette='Accent_r', ax=ax[8][1])
sns.stripplot(x="group", y="wsas_score_t2", data=t2_df, color=".15", ax=ax[8][1])
# Out:
# <AxesSubplot: xlabel='group', ylabel='wsas_score_t2'>

# %%
groups = t1_df.groupby('group')
hc = groups.get_group('HC')
an = groups.get_group('AN')

for col in an.columns:
    if col != 'G_Number' and col !='group':
        print(f'HC {col} mean', hc[col].mean(), 'std', hc[col].std())
        print(f'AN {col} mean', an[col].mean(), 'std', an[col].std(),'\n')
# Out:
# HC aq_score_t1 mean 2.4 std 1.8783517051407408
# AN aq_score_t1 mean 3.6914893617021276 std 2.2955150088377962
#
# HC anxiety_t1 mean 4.975 std 3.555331857279235
# AN anxiety_t1 mean 10.085106382978724 std 3.3908782586381743
#
# HC depression_t1 mean 3.2 std 2.756809750418044
# AN depression_t1 mean 7.329787234042553 std 3.7513819614790687
#
# HC bmi_t1 mean 22.70342915812874 std 2.8910039928981313
# AN bmi_t1 mean 18.16700378684451 std 2.7678106034910526
#
# HC oci_score_t1 mean 8.45 std 10.657728627018962
# AN oci_score_t1 mean 20.148936170212767 std 13.629472687445302
#
# HC wsas_score_t1 mean 3.375 std 7.392607187294685
# AN wsas_score_t1 mean 17.70212765957447 std 10.207344801539051
#
# HC restraint_score_t1 mean 0.5945945945945946 std 0.9907122395078913
# AN restraint_score_t1 mean 2.930337078651686 std 1.7157339251811858
#
# HC eating_concern_score_t1 mean 0.31351351351351353 std 0.8096096438826403
# AN eating_concern_score_t1 mean 2.5775280898876405 std 1.5431954565079664
#
# ...

# %%
groups = t2_df.groupby('group')
hc = groups.get_group('HC')
an = groups.get_group('AN')

for col in an.columns:
    if col != 'B_Number' and col !='group':
        print(f'HC {col} mean', hc[col].mean(), 'std', hc[col].std())
        print(f'AN {col} mean', an[col].mean(), 'std', an[col].std(),'\n')
# Out:
# HC aq_score_t2 mean 2.3 std 1.7715703594442809
# AN aq_score_t2 mean 3.75531914893617 std 2.2656204268487046
#
# HC anxiety_t2 mean 7.125 std 3.9754857790573443
# AN anxiety_t2 mean 11.074468085106384 std 4.637943931050982
#
# HC depression_t2 mean 4.45 std 3.587371010814294
# AN depression_t2 mean 6.6063829787234045 std 4.482266336092062
#
# HC bmi_t2 mean 24.13983786191713 std 4.684747708915129
# AN bmi_t2 mean 18.695693123820337 std 2.6853105396753025
#
# HC oci_score_t2 mean 10.95 std 10.578037237355131
# AN oci_score_t2 mean 20.54255319148936 std 14.776954517388495
#
# HC wsas_score_t2 mean 2.475 std 4.862137864703613
# AN wsas_score_t2 mean 14.404255319148936 std 11.150311388617965
#
# HC restraint_score_t2 mean 0.9650000000000001 std 1.1258159434212762
# AN restraint_score_t2 mean 2.3118279569892475 std 1.769627228978179
#
# HC eating_concern_score_t2 mean 0.445 std 0.5032968232640578
# AN eating_concern_score_t2 mean 2.002150537634408 std 1.6046959645455408
#
# ...

# %% [markdown]
# ## PCA description

# %%
fig,ax = plt.subplots(3,2, figsize=(10,10))
sns.boxplot(x='group', y='comp_1_t1', data=pca_df, linewidth=1, palette='Accent_r', ax=ax[0][0])
sns.stripplot(x="group", y="comp_1_t1", data=pca_df, color=".15", ax=ax[0][0])
sns.boxplot(x='group', y='comp_1_t2', data=pca_df, linewidth=1, palette='Accent_r', ax=ax[0][1])
sns.stripplot(x="group", y="comp_1_t2", data=pca_df, color=".15", ax=ax[0][1])

sns.boxplot(x='group', y='comp_2_t1', data=pca_df, linewidth=1, palette='Accent_r', ax=ax[1][0])
sns.stripplot(x="group", y="comp_2_t1", data=pca_df, color=".15", ax=ax[1][0])
sns.boxplot(x='group', y='comp_2_t2', data=pca_df, linewidth=1, palette='Accent_r', ax=ax[1][1])
sns.stripplot(x="group", y="comp_2_t2", data=pca_df, color=".15", ax=ax[1][1])

sns.boxplot(x='group', y='comp_3_t1', data=pca_df, linewidth=1, palette='Accent_r', ax=ax[2][0])
sns.stripplot(x="group", y="comp_3_t1", data=pca_df, color=".15", ax=ax[2][0])
sns.boxplot(x='group', y='comp_3_t2', data=pca_df, linewidth=1, palette='Accent_r', ax=ax[2][1])
sns.stripplot(x="group", y="comp_3_t2", data=pca_df, color=".15", ax=ax[2][1])
# Out:
# <AxesSubplot: xlabel='group', ylabel='comp_3_t2'>

# %%
dfs = {}

for component in comp:
    comp_df = pca_df[['G_Number', 
           f'{component}_t2', f'{component}_t1','group', 
           ]].rename(columns={f'{component}_t1':'t1', f'{component}_t2':'t2', 'G_Number':'participants'})
           
    comp_df['id'] = comp_df.index
    comp_df = pd.melt(comp_df, value_vars=['t2','t1'], id_vars='participants').sort_values(by=['participants'], ascending=True).reset_index(drop=True)
    comp_df['group'] = comp_df['participants'].apply(lambda group: 'HC' if 'G1' in group else 'AN')

    dfs[component] = comp_df

# %%
dfs['comp_1']
# Out:
#     participants variable     value group
# 0          G1002       t1 -3.081270    HC
# 1          G1002       t2 -3.409618    HC
# 2          G1004       t1 -2.366142    HC
# 3          G1004       t2  2.175929    HC
# 4          G1006       t1 -3.268447    HC
# ..           ...      ...       ...   ...
# 263        G2140       t2  3.998414    AN
# 264        G2141       t1  2.462581    AN
# 265        G2141       t2  2.025310    AN
# 266        G2142       t2 -0.361455    AN
# 267        G2142       t1  0.869857    AN
#
# [268 rows x 4 columns]

# %%
fig,ax = plt.subplots(3,1, figsize=(10,15))
sns.violinplot(x='group', y='value', hue='variable', data=dfs['comp_1'],  palette='Accent_r', ax=ax[0])
sns.violinplot(x='group', y='value', hue='variable', data=dfs['comp_2'],  palette='Accent_r', ax=ax[1])
sns.violinplot(x='group', y='value', hue='variable', data=dfs['comp_3'],  palette='Accent_r', ax=ax[2])
# Out:
# <AxesSubplot: xlabel='group', ylabel='value'>

# %%
fig,ax = plt.subplots(3,1, figsize=(10,20)) #Raincloud has an error where the hue box on the last plot is different
pt.RainCloud(x='group', y='value', data=dfs['comp_1'],  hue='variable', palette='Accent_r', alpha = .65, dodge = True, scale = "area", ax=ax[0], width_viol=.5)
pt.RainCloud(x='group', y='value', data=dfs['comp_2'],  hue='variable', palette='Accent_r', alpha = .65, dodge = True, scale = "area", ax=ax[1], width_viol=.5)
pt.RainCloud(x='group', y='value', data=dfs['comp_3'],  hue='variable', palette='Accent_r', alpha = .65, dodge = True, scale = "area", ax=ax[2], width_viol=.5)
# Out:
# <AxesSubplot: xlabel='group', ylabel='value'>

# %%
for component in comp:
    sns.lmplot(x=f'{component}_t1', y=f'{component}_t2', hue='group', data=pca_df)

# %%
groups = pca_df.groupby('group')
hc = groups.get_group('HC')
an = groups.get_group('AN')

for compent in comp:
    print('HC t1', compent, 'mean', hc[f'{compent}_t1'].mean(), 'std', hc[f'{compent}_t1'].std())
    print('HC t2', compent, 'mean', hc[f'{compent}_t2'].mean(), 'std', hc[f'{compent}_t2'].std(),'\n')
    print('AN t1', compent, 'mean', an[f'{compent}_t1'].mean(), 'std', an[f'{compent}_t1'].std())
    print('AN t2', compent, 'mean', an[f'{compent}_t2'].mean(), 'std', an[f'{compent}_t2'].std(),'\n')
# Out:
# HC t1 comp_1 mean -2.4997354930349673 std 1.5882322168563296
# HC t2 comp_1 mean -1.8595596979641436 std 1.2137512130139658
#
# AN t1 comp_1 mean 1.0637172310787095 std 1.9508624605035876
# AN t2 comp_1 mean 0.7913019991336783 std 2.293615818727557
#
# HC t1 comp_2 mean 0.021506136854517154 std 0.6512254549527074
# HC t2 comp_2 mean -0.1672285434958551 std 0.9132156887707651
#
# AN t1 comp_2 mean -0.009151547597666955 std 1.1269450037731312
# AN t2 comp_2 mean 0.07116108233866177 std 1.1192643902475443
#
# HC t1 comp_3 mean 0.47558306404308953 std 0.9881593097924444
# HC t2 comp_3 mean 0.5785403288214481 std 1.2033019482920562
#
# AN t1 comp_3 mean -0.2023757719332295 std 0.8676122779331042
# AN t2 comp_3 mean -0.24618737396657364 std 0.7055383684370934
